# %%
import gym
env = gym.make('Taxi-v2')
# Out:
# /home/pemfir/anaconda3/envs/deep_rl/lib/python3.7/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
print(env.observation_space)
print(env.action_space)
# Out:
# Discrete(500)
# Discrete(6)

# %%
for i_episode in range(1):
    state = env.reset()
    while True:
        action = env.action_space.sample()
        state, reward, done, info = env.step(action)
        print(action, state, reward, done, info)
        if done:
            print('End game! Reward: ', reward)
            print('You won :)\n') if reward > 0 else print('You lost :(\n')
            break
# Out:
# 1 146 -1 False {'prob': 1.0}
# 1 46 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 0 146 -1 False {'prob': 1.0}
# 2 166 -1 False {'prob': 1.0}
# 4 166 -10 False {'prob': 1.0}
# 1 66 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 5 46 -10 False {'prob': 1.0}
# 5 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 2 66 -1 False {'prob': 1.0}
# 5 66 -10 False {'prob': 1.0}
# 4 66 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 1 46 -1 False {'prob': 1.0}
# 0 146 -1 False {'prob': 1.0}
# 0 246 -1 False {'prob': 1.0}
# 1 146 -1 False {'prob': 1.0}
# 0 246 -1 False {'prob': 1.0}
# 3 226 -1 False {'prob': 1.0}
# 5 226 -10 False {'prob': 1.0}
# 2 246 -1 False {'prob': 1.0}
# 0 346 -1 False {'prob': 1.0}
# 1 246 -1 False {'prob': 1.0}
# 2 266 -1 False {'prob': 1.0}
# 1 166 -1 False {'prob': 1.0}
# 3 146 -1 False {'prob': 1.0}
# 1 46 -1 False {'prob': 1.0}
# 5 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 0 146 -1 False {'prob': 1.0}
# 2 166 -1 False {'prob': 1.0}
# 4 166 -10 False {'prob': 1.0}
# 5 166 -10 False {'prob': 1.0}
# 2 186 -1 False {'prob': 1.0}
# 4 186 -10 False {'prob': 1.0}
# 0 286 -1 False {'prob': 1.0}
# 1 186 -1 False {'prob': 1.0}
# 5 186 -10 False {'prob': 1.0}
# 5 186 -10 False {'prob': 1.0}
# 3 166 -1 False {'prob': 1.0}
# 3 146 -1 False {'prob': 1.0}
# 3 126 -1 False {'prob': 1.0}
# 0 226 -1 False {'prob': 1.0}
# 0 326 -1 False {'prob': 1.0}
# 5 326 -10 False {'prob': 1.0}
# 4 326 -10 False {'prob': 1.0}
# 2 346 -1 False {'prob': 1.0}
# 2 346 -1 False {'prob': 1.0}
# 1 246 -1 False {'prob': 1.0}
# 4 246 -10 False {'prob': 1.0}
# 0 346 -1 False {'prob': 1.0}
# 0 446 -1 False {'prob': 1.0}
# 3 426 -1 False {'prob': 1.0}
# 4 426 -10 False {'prob': 1.0}
# 4 426 -10 False {'prob': 1.0}
# 0 426 -1 False {'prob': 1.0}
# 4 426 -10 False {'prob': 1.0}
# 3 426 -1 False {'prob': 1.0}
# 3 426 -1 False {'prob': 1.0}
# 5 426 -10 False {'prob': 1.0}
# 0 426 -1 False {'prob': 1.0}
# 0 426 -1 False {'prob': 1.0}
# 4 426 -10 False {'prob': 1.0}
# 5 426 -10 False {'prob': 1.0}
# 4 426 -10 False {'prob': 1.0}
# 5 426 -10 False {'prob': 1.0}
# 5 426 -10 False {'prob': 1.0}
# 5 426 -10 False {'prob': 1.0}
# 2 446 -1 False {'prob': 1.0}
# 4 446 -10 False {'prob': 1.0}
# 4 446 -10 False {'prob': 1.0}
# 1 346 -1 False {'prob': 1.0}
# 5 346 -10 False {'prob': 1.0}
# 0 446 -1 False {'prob': 1.0}
# 4 446 -10 False {'prob': 1.0}
# 1 346 -1 False {'prob': 1.0}
# 4 346 -10 False {'prob': 1.0}
# 0 446 -1 False {'prob': 1.0}
# 2 446 -1 False {'prob': 1.0}
# 5 446 -10 False {'prob': 1.0}
# 5 446 -10 False {'prob': 1.0}
# 3 426 -1 False {'prob': 1.0}
# 0 426 -1 False {'prob': 1.0}
# 0 426 -1 False {'prob': 1.0}
# 1 326 -1 False {'prob': 1.0}
# 1 226 -1 False {'prob': 1.0}
# 1 126 -1 False {'prob': 1.0}
# 2 146 -1 False {'prob': 1.0}
# 1 46 -1 False {'prob': 1.0}
# 0 146 -1 False {'prob': 1.0}
# 1 46 -1 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 2 66 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 5 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 0 146 -1 False {'prob': 1.0}
# 1 46 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 5 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 1 46 -1 False {'prob': 1.0}
# 5 46 -10 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 3 46 -1 False {'prob': 1.0}
# 4 46 -10 False {'prob': 1.0}
# 0 146 -1 False {'prob': 1.0}
# 5 146 -10 False {'prob': 1.0}
# 2 166 -1 False {'prob': 1.0}
# 2 186 -1 False {'prob': 1.0}
# 5 186 -10 False {'prob': 1.0}
# 1 86 -1 False {'prob': 1.0}
# 5 86 -10 False {'prob': 1.0}
# 5 86 -10 False {'prob': 1.0}
# 2 86 -1 False {'prob': 1.0}
# 0 186 -1 False {'prob': 1.0}
# 2 186 -1 False {'prob': 1.0}
# 0 286 -1 False {'prob': 1.0}
# 0 386 -1 False {'prob': 1.0}
# 4 386 -10 False {'prob': 1.0}
# 2 386 -1 False {'prob': 1.0}
# 3 366 -1 False {'prob': 1.0}
# 5 366 -10 False {'prob': 1.0}
# 1 266 -1 False {'prob': 1.0}
# 3 246 -1 False {'prob': 1.0}
# 2 266 -1 False {'prob': 1.0}
# 2 286 -1 False {'prob': 1.0}
# 3 266 -1 False {'prob': 1.0}
# 4 266 -10 False {'prob': 1.0}
# 2 286 -1 False {'prob': 1.0}
# 4 286 -10 False {'prob': 1.0}
# 5 286 -10 False {'prob': 1.0}
# 5 286 -10 False {'prob': 1.0}
# 1 186 -1 False {'prob': 1.0}
# 2 186 -1 False {'prob': 1.0}
# 3 166 -1 False {'prob': 1.0}
# 4 166 -10 False {'prob': 1.0}
# 1 66 -1 False {'prob': 1.0}
# 0 166 -1 False {'prob': 1.0}
# 1 66 -1 False {'prob': 1.0}
# 4 66 -10 False {'prob': 1.0}
# 2 86 -1 False {'prob': 1.0}
# 2 86 -1 False {'prob': 1.0}
# 0 186 -1 False {'prob': 1.0}
# 4 186 -10 False {'prob': 1.0}
# 2 186 -1 False {'prob': 1.0}
# 2 186 -1 False {'prob': 1.0}
# 4 186 -10 False {'prob': 1.0}
# 1 86 -1 False {'prob': 1.0}
# 5 86 -10 False {'prob': 1.0}
# 3 66 -1 False {'prob': 1.0}
# 1 66 -1 False {'prob': 1.0}
# 4 66 -10 False {'prob': 1.0}
# 5 66 -10 False {'prob': 1.0}
# 1 66 -1 False {'prob': 1.0}
# 2 86 -1 False {'prob': 1.0}
# 5 86 -10 False {'prob': 1.0}
# 5 86 -10 False {'prob': 1.0}
# 4 98 -1 False {'prob': 1.0}
# 2 98 -1 False {'prob': 1.0}
# 2 98 -1 False {'prob': 1.0}
# 2 98 -1 False {'prob': 1.0}
# 5 86 -1 False {'prob': 1.0}
# 1 86 -1 False {'prob': 1.0}
# 3 66 -1 False {'prob': 1.0}
# 0 166 -1 False {'prob': 1.0}
# 3 146 -1 False {'prob': 1.0}
# 0 246 -1 False {'prob': 1.0}
# 4 246 -10 False {'prob': 1.0}
# 3 226 -1 False {'prob': 1.0}
# 5 226 -10 False {'prob': 1.0}
# 0 326 -1 False {'prob': 1.0}
# 2 346 -1 False {'prob': 1.0}
# 4 346 -10 False {'prob': 1.0}
# 3 326 -1 False {'prob': 1.0}
# 1 226 -1 False {'prob': 1.0}
# 4 226 -10 False {'prob': 1.0}
# 2 246 -1 False {'prob': 1.0}
# 2 266 -1 False {'prob': 1.0}
# 5 266 -10 False {'prob': 1.0}
# 2 286 -1 False {'prob': 1.0}
# 0 386 -1 False {'prob': 1.0}
# 3 366 -1 False {'prob': 1.0}
# 4 366 -10 False {'prob': 1.0}
# 3 366 -1 False {'prob': 1.0}
# 5 366 -10 True {'prob': 1.0}
# End game! Reward:  -10
# You lost :(
